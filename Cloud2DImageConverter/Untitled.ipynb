# %%
from Cloud2DImageConverter import api 
from PIL import Image
import numpy as np

# %%
api.run("../point_clouds/semantic_kitti/", "../results/")
# Out:
# Batch:: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:21<00:00, 21.44s/it]

# %%
mask = Image.open("../results/segmentation_mask/000001.png")
mask
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=L size=1024x64>

# %%
array = np.array(mask)
color_array = api.color_matrix(array)
img = Image.fromarray(color_array)
img
# Out:
# <PIL.Image.Image image mode=RGB size=1024x64>
